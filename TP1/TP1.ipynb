# %% [markdown]
# # <p style='color: red; text-align: center'>MACHINE LEARNING II - ТР 1</p>
#
#
# Objectif:
#
# L'objectif de ce TP est de se familiariser avec les outils essentiels du Reinforcement Learning(RL), notamment OpenAI Gym. Les étudiants vont explorer comment interagir avec un environnement RL et exécuter des actions avant d'implémenter un algorithme d'apprentissage dans les séances suivantes.

# %% [markdown]
# ## <p style='color: #87CEEB;'>A. Partie 1: Presentation des bibliotheque Cles</p>

# %% [markdown]
# 1. OpenAl Gym

# %% [markdown]
# - OpenAl Gym est une bibliothèque permettant de simuler des environnements interactifs pour tester des algorithmes de RL.
# - Un environnement Gym est défini par un ensemble d'états, d'actions, de récompenses et d'un critère de fin.

# %% [markdown]
# 2. Installation de Gym

# %%
# !pip install --upgrade gymnasium pygame numpy

# %% [markdown]
# 3. Création d'un environnement

# %%
import gymnasium as gym

env = gym.make('CartPole-v1', render_mode='human')
env.reset()
# Out:
# (array([-0.01499506, -0.00851779, -0.00355991, -0.02146894], dtype=float32),
#  {})

# %% [markdown]
# ## <p style='color: #87CEEB;'>B. Partie 2: Ecercices Pratiques avec OpenAI Gym</p>

# %% [markdown]
# ### <p style='color: #F88379;'>Exercice 1: Découverte et Exploration d'un Environnement Gym</p>

# %% [markdown]
# Objectif: Comprendre la structure d'un environnement Gym en explorant ses propriétés et ses actions possibles.
#
#
# ✔Instructions :
# 1. Afficher l'espace d'actions et l'espace d'observations.
# 2. Exécuter une boucle de simulation avec des actions aléatoires pendant 100 itérations.
# 3. Observer les valeurs des observations retournées.

# %%
print(f"Espace d'actions: {env.action_space}")
print(f"Espace d'observations: {env.observation_space}")

for _ in range(100):
    action = env.action_space.sample()
    observation, reward, done, _, _ = env.step(action)
    print(f"Action: {action}, Observation: {observation}, Reward: {reward}")
    if done:
        env.reset()

env.close()
# Out:
# Espace d'actions: Discrete(2)
# Espace d'observations: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
# Action: 0, Observation: [-0.01516542 -0.2035885  -0.00398929  0.27008867], Reward: 1.0
# Action: 1, Observation: [-0.01923719 -0.00840986  0.00141248 -0.02384983], Reward: 1.0
# Action: 1, Observation: [-0.01940538  0.1866918   0.00093549 -0.31608677], Reward: 1.0
# Action: 0, Observation: [-0.01567155 -0.00844345 -0.00538625 -0.02310896], Reward: 1.0
# Action: 1, Observation: [-0.01584042  0.18675533 -0.00584843 -0.31748644], Reward: 1.0
# Action: 0, Observation: [-0.01210531 -0.00828284 -0.01219816 -0.02665362], Reward: 1.0
# Action: 0, Observation: [-0.01227097 -0.20322776 -0.01273123  0.26215583], Reward: 1.0
# Action: 0, Observation: [-0.01633552 -0.39816567 -0.00748811  0.55079615], Reward: 1.0
# Action: 1, Observation: [-0.02429884 -0.20293936  0.00352781  0.25576338], Reward: 1.0
# Action: 0, Observation: [-0.02835762 -0.3981115   0.00864308  0.549557  ], Reward: 1.0
# Action: 1, Observation: [-0.03631985 -0.20311202  0.01963422  0.2596097 ], Reward: 1.0
# Action: 0, Observation: [-0.04038209 -0.39850867  0.02482641  0.5584203 ], Reward: 1.0
# Action: 0, Observation: [-0.04835227 -0.5939702   0.03599482  0.8588204 ], Reward: 1.0
# Action: 0, Observation: [-0.06023167 -0.7895635   0.05317122  1.1626004 ], Reward: 1.0
# Action: 0, Observation: [-0.07602294 -0.985336    0.07642324  1.4714692 ], Reward: 1.0
# Action: 0, Observation: [-0.09572966 -1.1813048   0.10585262  1.787011  ], Reward: 1.0
# Action: 1, Observation: [-0.11935575 -0.9875188   0.14159283  1.5290215 ], Reward: 1.0
# Action: 0, Observation: [-0.13910612 -1.1840361   0.17217326  1.8623369 ], Reward: 1.0
# Action: 1, Observation: [-0.16278686 -0.99116933  0.20942     1.6276833 ], Reward: 1.0
# Action: 0, Observation: [-0.18261024 -1.1880476   0.24197367  1.9776691 ], Reward: 1.0
# Action: 0, Observation: [-0.03695239 -0.2111146  -0.03039907  0.29226184], Reward: 1.0
# Action: 0, Observation: [-0.04117468 -0.40579024 -0.02455384  0.57520443], Reward: 1.0
# Action: 1, Observation: [-0.04929049 -0.21033283 -0.01304975  0.27488858], Reward: 1.0
# Action: 1, Observation: [-0.05349714 -0.01502714 -0.00755197 -0.02188151], Reward: 1.0
# Action: 0, Observation: [-0.05379769 -0.21003997 -0.0079896   0.26840913], Reward: 1.0
# Action: 1, Observation: [-0.05799849 -0.01480492 -0.00262142 -0.02678301], Reward: 1.0
# Action: 1, Observation: [-0.05829459  0.18035452 -0.00315708 -0.32029188], Reward: 1.0
# Action: 0, Observation: [-0.0546875  -0.01472233 -0.00956292 -0.02860624], Reward: 1.0
# Action: 1, Observation: [-0.05498194  0.18053545 -0.01013504 -0.32429096], Reward: 1.0
# Action: 0, Observation: [-0.05137123 -0.01444074 -0.01662086 -0.03482136], Reward: 1.0
# Action: 0, Observation: [-0.05166005 -0.20932044 -0.01731729  0.25257152], Reward: 1.0
# Action: 0, Observation: [-0.05584646 -0.4041909  -0.01226586  0.53974235], Reward: 1.0
# Action: 1, Observation: [-0.06393027 -0.20889868 -0.00147101  0.24321999], Reward: 1.0
# Action: 0, Observation: [-0.06810825 -0.4039996   0.00339339  0.53543854], Reward: 1.0
# Action: 1, Observation: [-0.07618824 -0.20892552  0.01410216  0.24382678], Reward: 1.0
# Action: 1, Observation: [-0.08036675 -0.01400781  0.01897869 -0.04437482], Reward: 1.0
# Action: 0, Observation: [-0.0806469  -0.20939669  0.0180912   0.25423512], Reward: 1.0
# Action: 0, Observation: [-0.08483484 -0.40477222  0.0231759   0.552569  ], Reward: 1.0
# Action: 1, Observation: [-0.09293029 -0.20998327  0.03422728  0.26727715], Reward: 1.0
# Action: 1, Observation: [-0.09712995 -0.0153661   0.03957282 -0.01441679], Reward: 1.0
# Action: 1, Observation: [-0.09743727  0.17916663  0.03928449 -0.29435608], Reward: 1.0
# Action: 0, Observation: [-0.09385394 -0.01649273  0.03339737  0.0104532 ], Reward: 1.0
# Action: 0, Observation: [-0.0941838  -0.21207733  0.03360643  0.3134835 ], Reward: 1.0
# Action: 1, Observation: [-0.09842534 -0.01744984  0.0398761   0.03158554], Reward: 1.0
# Action: 0, Observation: [-0.09877434 -0.21312027  0.04050781  0.33657834], Reward: 1.0
# Action: 1, Observation: [-0.10303674 -0.01859749  0.04723937  0.05693957], Reward: 1.0
# Action: 1, Observation: [-0.10340869  0.17581642  0.04837817 -0.22047275], Reward: 1.0
# Action: 0, Observation: [-0.09989236 -0.01996248  0.04396871  0.08706962], Reward: 1.0
# Action: 1, Observation: [-0.10029162  0.17450255  0.04571011 -0.19142336], Reward: 1.0
# Action: 1, Observation: [-0.09680156  0.36894178  0.04188164 -0.46934348], Reward: 1.0
# Action: 1, Observation: [-0.08942273  0.56344783  0.03249477 -0.7485371 ], Reward: 1.0
# Action: 0, Observation: [-0.07815377  0.36789307  0.01752402 -0.44580802], Reward: 1.0
# Action: 1, Observation: [-0.07079591  0.56276274  0.00860786 -0.7329159 ], Reward: 1.0
# Action: 0, Observation: [-0.05954065  0.36752293 -0.00605045 -0.43753633], Reward: 1.0
# Action: 0, Observation: [-0.0521902   0.17248715 -0.01480118 -0.14676683], Reward: 1.0
# Action: 1, Observation: [-0.04874045  0.3678179  -0.01773652 -0.44408223], Reward: 1.0
# Action: 1, Observation: [-0.04138409  0.5631862  -0.02661816 -0.74230295], Reward: 1.0
# Action: 0, Observation: [-0.03012037  0.36844164 -0.04146422 -0.45811433], Reward: 1.0
# Action: 1, Observation: [-0.02275154  0.56412446 -0.05062651 -0.7635733 ], Reward: 1.0
# Action: 1, Observation: [-0.01146905  0.7599058  -0.06589797 -1.0717468 ], Reward: 1.0
# Action: 1, Observation: [ 0.00372907  0.95583415 -0.08733291 -1.3843614 ], Reward: 1.0
# Action: 1, Observation: [ 0.02284575  1.15193    -0.11502013 -1.7030274 ], Reward: 1.0
# Action: 0, Observation: [ 0.04588435  0.95830494 -0.14908068 -1.4482503 ], Reward: 1.0
# Action: 1, Observation: [ 0.06505045  1.1549121  -0.17804569 -1.7835574 ], Reward: 1.0
# Action: 0, Observation: [ 0.08814869  0.96218264 -0.21371683 -1.5511026 ], Reward: 1.0
# Action: 0, Observation: [-0.0382234  -0.19542927  0.02351382  0.3171471 ], Reward: 1.0
# Action: 1, Observation: [-0.04213198 -0.00064998  0.02985676  0.03197139], Reward: 1.0
# Action: 0, Observation: [-0.04214498 -0.1961871   0.03049619  0.33392292], Reward: 1.0
# Action: 0, Observation: [-0.04606872 -0.3917295   0.03717465  0.63606465], Reward: 1.0
# Action: 0, Observation: [-0.05390331 -0.58734965  0.04989594  0.940219  ], Reward: 1.0
# Action: 1, Observation: [-0.06565031 -0.39293447  0.06870032  0.66362244], Reward: 1.0
# Action: 0, Observation: [-0.07350899 -0.5889415   0.08197277  0.9771215 ], Reward: 1.0
# Action: 1, Observation: [-0.08528782 -0.3950088   0.1015152   0.7112722 ], Reward: 1.0
# Action: 1, Observation: [-0.093188   -0.20142817  0.11574064  0.45219043], Reward: 1.0
# Action: 1, Observation: [-0.09721657 -0.00811694  0.12478445  0.1981154 ], Reward: 1.0
# Action: 1, Observation: [-0.0973789   0.18501979  0.12874676 -0.05274561], Reward: 1.0
# Action: 1, Observation: [-0.09367851  0.37808314  0.12769185 -0.30219677], Reward: 1.0
# Action: 1, Observation: [-0.08611684  0.5711759   0.12164791 -0.5520383 ], Reward: 1.0
# Action: 1, Observation: [-0.07469333  0.7643983   0.11060715 -0.80405366], Reward: 1.0
# Action: 0, Observation: [-0.05940536  0.56794775  0.09452607 -0.47872627], Reward: 1.0
# Action: 0, Observation: [-0.04804641  0.37162727  0.08495155 -0.15781094], Reward: 1.0
# Action: 0, Observation: [-0.04061386  0.17539826  0.08179533  0.16041681], Reward: 1.0
# Action: 0, Observation: [-0.0371059  -0.02079364  0.08500367  0.47774178], Reward: 1.0
# Action: 1, Observation: [-0.03752177  0.17303176  0.0945585   0.21301441], Reward: 1.0
# Action: 0, Observation: [-0.03406113 -0.02330597  0.09881879  0.53396416], Reward: 1.0
# Action: 0, Observation: [-0.03452725 -0.21966863  0.10949807  0.85607666], Reward: 1.0
# Action: 0, Observation: [-0.03892063 -0.41609865  0.1266196   1.1810852 ], Reward: 1.0
# Action: 1, Observation: [-0.0472426  -0.22282691  0.15024132  0.93062526], Reward: 1.0
# Action: 1, Observation: [-0.05169914 -0.03001696  0.16885382  0.68867326], Reward: 1.0
# Action: 0, Observation: [-0.05229948 -0.22702987  0.18262728  1.0293972 ], Reward: 1.0
# Action: 1, Observation: [-0.05684008 -0.03474553  0.20321523  0.79916173], Reward: 1.0
# Action: 0, Observation: [-0.05753499 -0.23198871  0.21919847  1.1482733 ], Reward: 1.0
# Action: 1, Observation: [ 0.02683419  0.15602972  0.01647439 -0.27653885], Reward: 1.0
# Action: 1, Observation: [ 0.02995479  0.3509128   0.01094361 -0.5639806 ], Reward: 1.0
# Action: 1, Observation: [ 3.6973044e-02  5.4587954e-01 -3.3599915e-04 -8.5319573e-01], Reward: 1.0
# Action: 1, Observation: [ 0.04789063  0.741006   -0.01739991 -1.1459843 ], Reward: 1.0
# Action: 1, Observation: [ 0.06271075  0.9363509  -0.0403196  -1.4440725 ], Reward: 1.0
# Action: 1, Observation: [ 0.08143777  1.1319451  -0.06920105 -1.7490762 ], Reward: 1.0
# Action: 0, Observation: [ 0.10407668  0.9376741  -0.10418258 -1.478696  ], Reward: 1.0
# Action: 0, Observation: [ 0.12283015  0.74396694 -0.13375649 -1.2202849 ], Reward: 1.0

# %% [markdown]
# ### <p style='color: #F88379;'>Exercice 2: Manipulation des Observations et Récompenses</p>

# %% [markdown]
# Objectif: Comprendre comment récupérer les observations et les récompenses lors de l'interaction avec l'environnement.
#
#
# ✔Instructions:
# 1. Prendre une action et récupérer les valeurs retournées (observation, reward, done).
# 2. Afficher ces valeurs et analyser leur signification.
# 3. Faire plusieurs essais et noter les variations des observations et des récompenses.

# %%
# Création de l'environnement
env = gym.make("CartPole-v1", render_mode='human')
observation, info = env.reset()

# Faire plusieurs essais
for i in range(100):
    action = env.action_space.sample()  # Action aléatoire
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated

    print(f"Essai {i + 1}")
    print(f"Action choisie : {action}")
    print(f"Observation : {observation}")
    print(f"Récompense : {reward}")
    print(f"Épisode terminé ? : {done}")
    print("-" * 40)

    if done:
        print("L’épisode est terminé. Réinitialisation de l’environnement.\n")
        observation, info = env.reset()

env.close()
# Out:
# Essai 1
# Action choisie : 0
# Observation : [ 0.03224588 -0.1802814   0.01445511  0.25186682]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 2
# Action choisie : 0
# Observation : [ 0.02864025 -0.37560675  0.01949245  0.5490739 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 3
# Action choisie : 0
# Observation : [ 0.02112812 -0.570997    0.03047393  0.84783405]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 4
# Action choisie : 0
# Observation : [ 0.00970817 -0.7665211   0.04743061  1.1499419 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 5
# Action choisie : 0
# Observation : [-0.00562225 -0.9622289   0.07042944  1.4571128 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 6
# Action choisie : 0
# Observation : [-0.02486682 -1.1581408   0.0995717   1.7709414 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 7
# Action choisie : 0
# Observation : [-0.04802964 -1.3542354   0.13499053  2.092852  ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 8
# Action choisie : 1
# Observation : [-0.07511435 -1.1607074   0.17684756  1.8447677 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 9
# Action choisie : 1
# Observation : [-0.09832849 -0.9679216   0.21374293  1.6118219 ]
# Récompense : 1.0
# Épisode terminé ? : True
# ----------------------------------------
# L’épisode est terminé. Réinitialisation de l’environnement.
#
# Essai 10
# Action choisie : 0
# Observation : [-0.01344656 -0.17707163  0.00812206  0.30293828]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 11
# Action choisie : 1
# Observation : [-0.01698799  0.01793363  0.01418082  0.01282791]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 12
# Action choisie : 0
# Observation : [-0.01662932 -0.17738879  0.01443738  0.3099511 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 13
# Action choisie : 1
# Observation : [-0.0201771   0.01752452  0.0206364   0.02185606]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 14
# Action choisie : 1
# Observation : [-0.0198266   0.21234454  0.02107353 -0.26424506]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 15
# Action choisie : 1
# Observation : [-0.01557971  0.40715945  0.01578862 -0.55020744]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 16
# Action choisie : 1
# Observation : [-0.00743653  0.60205615  0.00478448 -0.8378743 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 17
# Action choisie : 0
# Observation : [ 0.0046046   0.40686917 -0.01197301 -0.54369056]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 18
# Action choisie : 0
# Observation : [ 0.01274198  0.21191749 -0.02284682 -0.25480404]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 19
# Action choisie : 0
# Observation : [ 0.01698033  0.01712908 -0.0279429   0.03058596]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 20
# Action choisie : 0
# Observation : [ 0.01732291 -0.17758125 -0.02733118  0.31432328]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 21
# Action choisie : 0
# Observation : [ 0.01377129 -0.37230343 -0.02104472  0.5982631 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 22
# Action choisie : 1
# Observation : [ 0.00632522 -0.17689343 -0.00907946  0.2990263 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 23
# Action choisie : 1
# Observation : [ 0.00278735  0.01835677 -0.00309893  0.00349377]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 24
# Action choisie : 1
# Observation : [ 0.00315449  0.21352303 -0.00302905 -0.29016528]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 25
# Action choisie : 1
# Observation : [ 0.00742495  0.40868804 -0.00883236 -0.583802  ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 26
# Action choisie : 1
# Observation : [ 0.01559871  0.6039326  -0.0205084  -0.8792541 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 27
# Action choisie : 0
# Observation : [ 0.02767736  0.4090952  -0.03809348 -0.5930885 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 28
# Action choisie : 1
# Observation : [ 0.03585926  0.6047291  -0.04995525 -0.8975233 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 29
# Action choisie : 0
# Observation : [ 0.04795384  0.41031864 -0.06790572 -0.62095207]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 30
# Action choisie : 1
# Observation : [ 0.05616022  0.6063199  -0.08032476 -0.9342253 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 31
# Action choisie : 0
# Observation : [ 0.06828661  0.41236803 -0.09900927 -0.66782564]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 32
# Action choisie : 0
# Observation : [ 0.07653397  0.21875216 -0.11236578 -0.40788537]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 33
# Action choisie : 1
# Observation : [ 0.08090902  0.41527307 -0.12052349 -0.7337738 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 34
# Action choisie : 1
# Observation : [ 0.08921448  0.6118358  -0.13519897 -1.0618272 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 35
# Action choisie : 0
# Observation : [ 0.1014512   0.41873765 -0.1564355  -0.8144507 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 36
# Action choisie : 1
# Observation : [ 0.10982595  0.6156162  -0.17272452 -1.151967  ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 37
# Action choisie : 1
# Observation : [ 0.12213828  0.81251824 -0.19576386 -1.4934541 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 38
# Action choisie : 0
# Observation : [ 0.13838863  0.62024164 -0.22563295 -1.2677358 ]
# Récompense : 1.0
# Épisode terminé ? : True
# ----------------------------------------
# L’épisode est terminé. Réinitialisation de l’environnement.
#
# Essai 39
# Action choisie : 0
# Observation : [-0.04578779 -0.20711799 -0.00342421  0.26888564]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 40
# Action choisie : 0
# Observation : [-0.04993015 -0.40219092  0.00195351  0.5604866 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 41
# Action choisie : 1
# Observation : [-0.05797397 -0.20709643  0.01316324  0.26841977]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 42
# Action choisie : 0
# Observation : [-0.0621159  -0.40240374  0.01853164  0.56522524]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 43
# Action choisie : 1
# Observation : [-0.07016397 -0.20754662  0.02983614  0.27843773]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 44
# Action choisie : 0
# Observation : [-0.0743149  -0.4030812   0.03540489  0.5803796 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 45
# Action choisie : 1
# Observation : [-0.08237652 -0.20847282  0.04701249  0.2990568 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 46
# Action choisie : 1
# Observation : [-0.08654598 -0.01405141  0.05299362  0.02156351]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 47
# Action choisie : 1
# Observation : [-0.08682701  0.18027209  0.05342489 -0.25393972]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 48
# Action choisie : 1
# Observation : [-0.08322157  0.37459213  0.0483461  -0.52930444]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 49
# Action choisie : 0
# Observation : [-0.07572973  0.17882456  0.03776001 -0.22178799]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 50
# Action choisie : 1
# Observation : [-0.07215324  0.373387    0.03332425 -0.5023248 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 51
# Action choisie : 0
# Observation : [-0.06468549  0.17781158  0.02327775 -0.19932905]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 52
# Action choisie : 0
# Observation : [-0.06112926 -0.01763543  0.01929117  0.10060509]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 53
# Action choisie : 0
# Observation : [-0.06148198 -0.21302848  0.02130327  0.39931136]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 54
# Action choisie : 0
# Observation : [-0.06574254 -0.40844604  0.0292895   0.6986339 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 55
# Action choisie : 1
# Observation : [-0.07391147 -0.21374218  0.04326218  0.41531324]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 56
# Action choisie : 1
# Observation : [-0.07818631 -0.01925924  0.05156844  0.1365769 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 57
# Action choisie : 1
# Observation : [-0.07857149  0.17508762  0.05429998 -0.13940142]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 58
# Action choisie : 0
# Observation : [-0.07506974 -0.02076831  0.05151195  0.1699058 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 59
# Action choisie : 1
# Observation : [-0.07548511  0.17357993  0.05491007 -0.10609207]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 60
# Action choisie : 0
# Observation : [-0.0720135  -0.02228415  0.05278823  0.20339671]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 61
# Action choisie : 1
# Observation : [-0.07245919  0.1720447   0.05685616 -0.07217797]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 62
# Action choisie : 0
# Observation : [-0.0690183  -0.02384433  0.0554126   0.23788747]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 63
# Action choisie : 0
# Observation : [-0.06949519 -0.21971233  0.06017035  0.5475215 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 64
# Action choisie : 1
# Observation : [-0.07388943 -0.02548504  0.07112078  0.27438718]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 65
# Action choisie : 1
# Observation : [-0.07439913  0.16855389  0.07660852  0.00495648]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 66
# Action choisie : 0
# Observation : [-0.07102805 -0.02757838  0.07670765  0.32079288]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 67
# Action choisie : 1
# Observation : [-0.07157962  0.16637214  0.08312351  0.05325255]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 68
# Action choisie : 1
# Observation : [-0.06825218  0.3602099   0.08418857 -0.21209002]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 69
# Action choisie : 0
# Observation : [-0.06104798  0.16399148  0.07994676  0.10591739]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 70
# Action choisie : 0
# Observation : [-0.05776815 -0.03217972  0.08206511  0.42271364]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 71
# Action choisie : 1
# Observation : [-0.05841174  0.16168955  0.09051938  0.15698852]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 72
# Action choisie : 0
# Observation : [-0.05517795 -0.03460397  0.09365916  0.4767997 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 73
# Action choisie : 1
# Observation : [-0.05587003  0.1590794   0.10319515  0.2150435 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 74
# Action choisie : 1
# Observation : [-0.05268845  0.35258627  0.10749602 -0.04338709]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 75
# Action choisie : 1
# Observation : [-0.04563672  0.5460157   0.10662828 -0.30031347]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 76
# Action choisie : 0
# Observation : [-0.0347164   0.3495483   0.10062201  0.02400324]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 77
# Action choisie : 0
# Observation : [-0.02772544  0.15313807  0.10110207  0.34666136]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 78
# Action choisie : 1
# Observation : [-0.02466268  0.3466875   0.1080353   0.08749314]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 79
# Action choisie : 0
# Observation : [-0.01772893  0.15019615  0.10978516  0.41221243]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 80
# Action choisie : 1
# Observation : [-0.01472501  0.34360453  0.11802941  0.15605849]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 81
# Action choisie : 1
# Observation : [-0.00785291  0.5368562   0.12115058 -0.09718204]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 82
# Action choisie : 1
# Observation : [ 0.00288421  0.73005223  0.11920694 -0.34932083]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 83
# Action choisie : 1
# Observation : [ 0.01748525  0.9232949   0.11222053 -0.60216385]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 84
# Action choisie : 1
# Observation : [ 0.03595115  1.1166831   0.10017724 -0.8574979 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 85
# Action choisie : 1
# Observation : [ 0.05828481  1.310308    0.08302729 -1.1170762 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 86
# Action choisie : 0
# Observation : [ 0.08449097  1.1142005   0.06068576 -0.7995462 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 87
# Action choisie : 1
# Observation : [ 0.10677498  1.3084397   0.04469484 -1.0725381 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 88
# Action choisie : 0
# Observation : [ 0.13294378  1.1127564   0.02324408 -0.7661703 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 89
# Action choisie : 1
# Observation : [ 0.1551989   1.3075507   0.00792067 -1.0514498 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 90
# Action choisie : 0
# Observation : [ 0.18134992  1.1123246  -0.01310832 -0.75629115]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 91
# Action choisie : 0
# Observation : [ 0.20359641  0.91738576 -0.02823415 -0.46776173]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 92
# Action choisie : 0
# Observation : [ 0.22194412  0.72267383 -0.03758938 -0.18410999]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 93
# Action choisie : 0
# Observation : [ 0.2363976   0.5281093  -0.04127158  0.09648194]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 94
# Action choisie : 1
# Observation : [ 0.24695979  0.72379774 -0.03934194 -0.20893113]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 95
# Action choisie : 0
# Observation : [ 0.26143575  0.5292598  -0.04352056  0.07108647]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 96
# Action choisie : 0
# Observation : [ 0.27202094  0.3347879  -0.04209884  0.34972706]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 97
# Action choisie : 1
# Observation : [ 0.27871668  0.53048253 -0.03510429  0.04407183]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 98
# Action choisie : 1
# Observation : [ 0.28932634  0.72608984 -0.03422286 -0.25947687]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 99
# Action choisie : 1
# Observation : [ 0.30384815  0.9216832  -0.03941239 -0.5627547 ]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------
# Essai 100
# Action choisie : 1
# Observation : [ 0.3222818   1.1173353  -0.05066749 -0.86758935]
# Récompense : 1.0
# Épisode terminé ? : False
# ----------------------------------------

# %% [markdown]
# ### <p style='color: #F88379;'>Exercice 3: Contrôle Manuel de l'Agent</p>

# %% [markdown]
# Objectif: Permettre à l'utilisateur de contrôler manuellement l'agent pour mieux comprendre l'effet des actions.
#
# ✔Instructions:
#
# 1. Demander à l'utilisateur d'entrer une action (o ou 1).
# 2. Exécuter l'action dans l'environnement et afficher les nouvelles observations.
# 3. Répéter l'opération jusqu'à la fin de l'épisode.
# 4. Afficher la durée totale de l'épisode avant qu'il ne se termine.

# %%
# Création de l’environnement
env = gym.make("CartPole-v1", render_mode=None)
observation, info = env.reset()
done = False
step_count = 0  # Durée de l’épisode (en nombre d’actions)

print("🎮 Contrôle manuel : entre 0 (gauche) ou 1 (droite)")

while not done:
    # Afficher l’état courant
    print(f"\n🟡 Observation actuelle : {observation}")

    # Demander l'action à l'utilisateur
    user_input = input("Tape ton action (0=gauche, 1=droite) : ")

    # Vérification de l’entrée
    if user_input not in ["0", "1"]:
        print("⛔ Entrée invalide. Merci de taper uniquement 0 ou 1.")
        continue

    action = int(user_input)

    # Appliquer l’action
    observation, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    step_count += 1

    # Afficher les infos après action
    print(f"✅ Action effectuée : {action}")
    print(f"🔄 Nouvelle observation : {observation}")
    print(f"⭐ Récompense reçue : {reward}")

# Fin de l’épisode
print("\n💥 L’épisode est terminé.")
print(f"📊 Durée totale de l’épisode : {step_count} étapes.")

env.close()
# Out:
# 🎮 Contrôle manuel : entre 0 (gauche) ou 1 (droite)
#
# 🟡 Observation actuelle : [ 0.03233825  0.01587461 -0.02911318  0.02651938]
# ✅ Action effectuée : 0
# 🔄 Nouvelle observation : [ 0.03265574 -0.178818   -0.02858279  0.30987647]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.03265574 -0.178818   -0.02858279  0.30987647]
# ✅ Action effectuée : 0
# 🔄 Nouvelle observation : [ 0.02907938 -0.3735213  -0.02238526  0.59340996]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.02907938 -0.3735213  -0.02238526  0.59340996]
# ✅ Action effectuée : 0
# 🔄 Nouvelle observation : [ 0.02160896 -0.5683229  -0.01051706  0.87895834]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.02160896 -0.5683229  -0.01051706  0.87895834]
# ⛔ Entrée invalide. Merci de taper uniquement 0 ou 1.
#
# 🟡 Observation actuelle : [ 0.02160896 -0.5683229  -0.01051706  0.87895834]
# ✅ Action effectuée : 0
# 🔄 Nouvelle observation : [ 0.0102425  -0.76330036  0.00706211  1.1683165 ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.0102425  -0.76330036  0.00706211  1.1683165 ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.00502351 -0.568271    0.03042844  0.87785596]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.00502351 -0.568271    0.03042844  0.87785596]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.01638893 -0.37357545  0.04798556  0.59489244]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.01638893 -0.37357545  0.04798556  0.59489244]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.02386044 -0.17915681  0.0598834   0.31770247]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.02386044 -0.17915681  0.0598834   0.31770247]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.02744357  0.01506337  0.06623746  0.04448961]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.02744357  0.01506337  0.06623746  0.04448961]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.0271423   0.20917606  0.06712725 -0.22658134]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.0271423   0.20917606  0.06712725 -0.22658134]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.02295878  0.40327767  0.06259562 -0.4973574 ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.02295878  0.40327767  0.06259562 -0.4973574 ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.01489323  0.5974637   0.05264847 -0.76967496]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.01489323  0.5974637   0.05264847 -0.76967496]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [-0.00294396  0.791823    0.03725497 -1.0453385 ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [-0.00294396  0.791823    0.03725497 -1.0453385 ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [ 0.01289251  0.9864312   0.0163482  -1.3260977 ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.01289251  0.9864312   0.0163482  -1.3260977 ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [ 0.03262113  1.181343   -0.01017375 -1.61362   ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.03262113  1.181343   -0.01017375 -1.61362   ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [ 0.05624799  1.3765835  -0.04244615 -1.9094567 ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.05624799  1.3765835  -0.04244615 -1.9094567 ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [ 0.08377966  1.5721368  -0.08063529 -2.2149978 ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.08377966  1.5721368  -0.08063529 -2.2149978 ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [ 0.11522239  1.7679316  -0.12493525 -2.531417  ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.11522239  1.7679316  -0.12493525 -2.531417  ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [ 0.15058102  1.9638251  -0.17556359 -2.8596025 ]
# ⭐ Récompense reçue : 1.0
#
# 🟡 Observation actuelle : [ 0.15058102  1.9638251  -0.17556359 -2.8596025 ]
# ✅ Action effectuée : 1
# 🔄 Nouvelle observation : [ 0.18985753  2.159583   -0.23275563 -3.2000766 ]
# ⭐ Récompense reçue : 1.0
#
# 💥 L’épisode est terminé.
# 📊 Durée totale de l’épisode : 19 étapes.

# %% [markdown]
# ### <p style='color: #F88379;'>Exercice 4: Évaluation des Performances d'une Politique Aléatoire</p>

# %% [markdown]
# Objectif: Mesurer la durée moyenne d'un épisode lorsqu'un agent prend des actions aléatoires.
#
#
# ✔Instructions:
#
# 1. Faire exécuter à l'agent des actions aléatoires pendant plusieurs épisodes (ex: 10 épisodes).
# 2. Calculer la durée moyenne avant que l'épisode ne se termine.
# 3. Comparer les résultats entre plusieurs exécutions.

# %%
env = gym.make("CartPole-v1", render_mode=None)
num_episodes = 10
durations = []

for episode in range(num_episodes):
    observation, info = env.reset()
    done = False
    step_count = 0

    while not done:
        action = env.action_space.sample()  # Action aléatoire
        observation, reward, terminated, truncated, info = env.step(action)
        done = terminated or truncated
        step_count += 1

    durations.append(step_count)
    print(f"🎬 Épisode {episode + 1} terminé après {step_count} étapes.")

env.close()

# Moyenne
average_duration = sum(durations) / num_episodes
print("\n📊 Résultats sur 10 épisodes aléatoires :")
print(f"Durées des épisodes : {durations}")
print(f"Durée moyenne : {average_duration:.2f} étapes")
# Out:
# 🎬 Épisode 1 terminé après 11 étapes.
# 🎬 Épisode 2 terminé après 16 étapes.
# 🎬 Épisode 3 terminé après 19 étapes.
# 🎬 Épisode 4 terminé après 18 étapes.
# 🎬 Épisode 5 terminé après 9 étapes.
# 🎬 Épisode 6 terminé après 20 étapes.
# 🎬 Épisode 7 terminé après 34 étapes.
# 🎬 Épisode 8 terminé après 11 étapes.
# 🎬 Épisode 9 terminé après 13 étapes.
# 🎬 Épisode 10 terminé après 39 étapes.
#
# 📊 Résultats sur 10 épisodes aléatoires :
# Durées des épisodes : [11, 16, 19, 18, 9, 20, 34, 11, 13, 39]
# Durée moyenne : 19.00 étapes
